# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('files/tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
type(df['total_bill']) # each colum is a series
# Out:
# pandas.core.series.Series

# %%
type(df[['total_bill','tip']]) # more than one column is always a dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
# add a new coulmn
df['tip%'] = np.round((df['tip'] / df['total_bill'] * 100), 2) # rounding to 2 decimals

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID   tip%
# ...

# %%
# remove cols
df = df.drop('size', axis=1) # need to mention column by saying axis as 1 otherwise it will look for index row

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner              6.15
# ..          ...   ...     ...    ...   ...     ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner              9.39
#
#              Payer Name         CC Number Payment ID   tip%
# 0    Christy Cunningham  3560325168603410    Sun2959   5.94
# ...

# %%
# drop row by passing index
df = df.drop(0)

# %%
df = df.drop([1,2,3])

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  price_per_person  \
# 4         24.59  3.61  Female     No   Sun  Dinner              6.15
# 5         25.29  4.71    Male     No   Sun  Dinner              6.32
# 6          8.77  2.00    Male     No   Sun  Dinner              4.38
# 7         26.88  3.12    Male     No   Sun  Dinner              6.72
# 8         15.04  1.96    Male     No   Sun  Dinner              7.52
# ..          ...   ...     ...    ...   ...     ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner              9.39
#
#              Payer Name         CC Number Payment ID   tip%
# 4          Tonya Carter  4832732618637221    Sun2251  14.68
# ...

# %% [markdown]
# # focus on rows now

# %%
df.index
# Out:
# RangeIndex(start=4, stop=244, step=1)

# %%
# set one of the column as index
# note: index should be unique but not mandatory
df = df.set_index('Payment ID')

# %%
df.index
# Out:
# Index(['Sun2251', 'Sun9679', 'Sun5985', 'Sun8157', 'Sun6820', 'Sun3775',
#        'Sun2546', 'Sun6686', 'Sun1300', 'Sun2971',
#        ...
#        'Sat7220', 'Sat4615', 'Sat5032', 'Sat2929', 'Sat9777', 'Sat2657',
#        'Sat1766', 'Sat3880', 'Sat17', 'Thur672'],
#       dtype='object', name='Payment ID', length=240)

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  price_per_person  \
# Payment ID
# Sun2251          24.59  3.61  Female     No   Sun  Dinner              6.15
# Sun9679          25.29  4.71    Male     No   Sun  Dinner              6.32
# Sun5985           8.77  2.00    Male     No   Sun  Dinner              4.38
# Sun8157          26.88  3.12    Male     No   Sun  Dinner              6.72
# Sun6820          15.04  1.96    Male     No   Sun  Dinner              7.52
# ...                ...   ...     ...    ...   ...     ...               ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner              9.68
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner             13.59
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner             11.34
# Sat17            17.82  1.75    Male     No   Sat  Dinner              8.91
# Thur672          18.78  3.00  Female     No  Thur  Dinner              9.39
#
# ...

# %%
# reset the index to default integer index
df = df.reset_index()

# %%
df
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  \
# 0      Sun2251       24.59  3.61  Female     No   Sun  Dinner
# 1      Sun9679       25.29  4.71    Male     No   Sun  Dinner
# 2      Sun5985        8.77  2.00    Male     No   Sun  Dinner
# 3      Sun8157       26.88  3.12    Male     No   Sun  Dinner
# 4      Sun6820       15.04  1.96    Male     No   Sun  Dinner
# ..         ...         ...   ...     ...    ...   ...     ...
# 235    Sat2657       29.03  5.92    Male     No   Sat  Dinner
# 236    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner
# 237    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner
# 238      Sat17       17.82  1.75    Male     No   Sat  Dinner
# 239    Thur672       18.78  3.00  Female     No  Thur  Dinner
#
#      price_per_person          Payer Name         CC Number   tip%
# 0                6.15        Tonya Carter  4832732618637221  14.68
# 1                6.32          Erik Smith   213140353657882  18.62
# ...

# %%
df = df.set_index('Payment ID')

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  price_per_person  \
# Payment ID
# Sun2251          24.59  3.61  Female     No   Sun  Dinner              6.15
# Sun9679          25.29  4.71    Male     No   Sun  Dinner              6.32
# Sun5985           8.77  2.00    Male     No   Sun  Dinner              4.38
# Sun8157          26.88  3.12    Male     No   Sun  Dinner              6.72
# Sun6820          15.04  1.96    Male     No   Sun  Dinner              7.52
# ...                ...   ...     ...    ...   ...     ...               ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner              9.68
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner             13.59
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner             11.34
# Sat17            17.82  1.75    Male     No   Sat  Dinner              8.91
# Thur672          18.78  3.00  Female     No  Thur  Dinner              9.39
#
# ...

# %%
# passing default ineteger index to find a row
df.iloc[0]
# Out:
# total_bill                     24.59
# tip                             3.61
# sex                           Female
# smoker                            No
# day                              Sun
# time                          Dinner
# price_per_person                6.15
# Payer Name              Tonya Carter
# CC Number           4832732618637221
# tip%                           14.68
# Name: Sun2251, dtype: object

# %%
# passing actual index to find a row
df.loc['Sun2251']
# Out:
# total_bill                     24.59
# tip                             3.61
# sex                           Female
# smoker                            No
# day                              Sun
# time                          Dinner
# price_per_person                6.15
# Payer Name              Tonya Carter
# CC Number           4832732618637221
# tip%                           14.68
# Name: Sun2251, dtype: object

# %%
# select range of integer index values
df.iloc[0:4]
# Out:
#             total_bill   tip     sex smoker  day    time  price_per_person  \
# Payment ID
# Sun2251          24.59  3.61  Female     No  Sun  Dinner              6.15
# Sun9679          25.29  4.71    Male     No  Sun  Dinner              6.32
# Sun5985           8.77  2.00    Male     No  Sun  Dinner              4.38
# Sun8157          26.88  3.12    Male     No  Sun  Dinner              6.72
#
#                     Payer Name         CC Number   tip%
# Payment ID
# Sun2251           Tonya Carter  4832732618637221  14.68
# Sun9679             Erik Smith   213140353657882  18.62
# Sun5985     Kristopher Johnson  2223727524230344  22.81
# Sun8157            Robert Buck  3514785077705092  11.61

# %%
df.iloc[[0,1,2,3,9]]
# Out:
#             total_bill   tip     sex smoker  day    time  price_per_person  \
# Payment ID
# Sun2251          24.59  3.61  Female     No  Sun  Dinner              6.15
# Sun9679          25.29  4.71    Male     No  Sun  Dinner              6.32
# Sun5985           8.77  2.00    Male     No  Sun  Dinner              4.38
# Sun8157          26.88  3.12    Male     No  Sun  Dinner              6.72
# Sun2971          18.43  3.00    Male     No  Sun  Dinner              4.61
#
#                     Payer Name         CC Number   tip%
# Payment ID
# Sun2251           Tonya Carter  4832732618637221  14.68
# Sun9679             Erik Smith   213140353657882  18.62
# Sun5985     Kristopher Johnson  2223727524230344  22.81
# Sun8157            Robert Buck  3514785077705092  11.61
# Sun2971           Joshua Jones  6011163105616890  16.28

# %%
df.loc[['Sun2251', 'Sun5985']]
# Out:
#             total_bill   tip     sex smoker  day    time  price_per_person  \
# Payment ID
# Sun2251          24.59  3.61  Female     No  Sun  Dinner              6.15
# Sun5985           8.77  2.00    Male     No  Sun  Dinner              4.38
#
#                     Payer Name         CC Number   tip%
# Payment ID
# Sun2251           Tonya Carter  4832732618637221  14.68
# Sun5985     Kristopher Johnson  2223727524230344  22.81

# %%
df = df.drop('Sun2251',axis=0) # axis 0 is default

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  price_per_person  \
# Payment ID
# Sun9679          25.29  4.71    Male     No   Sun  Dinner              6.32
# Sun5985           8.77  2.00    Male     No   Sun  Dinner              4.38
# Sun8157          26.88  3.12    Male     No   Sun  Dinner              6.72
# Sun6820          15.04  1.96    Male     No   Sun  Dinner              7.52
# Sun3775          14.78  3.23    Male     No   Sun  Dinner              7.39
# ...                ...   ...     ...    ...   ...     ...               ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner              9.68
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner             13.59
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner             11.34
# Sat17            17.82  1.75    Male     No   Sat  Dinner              8.91
# Thur672          18.78  3.00  Female     No  Thur  Dinner              9.39
#
# ...

# %% [markdown]
# # note: once you change the index from default to some other column then you cannot drop by integer index anymore

# %%
# add one row in dataframe
one_row = df.iloc[0]

# %%
one_row
# Out:
# total_bill                    25.29
# tip                            4.71
# sex                            Male
# smoker                           No
# day                             Sun
# time                         Dinner
# price_per_person               6.32
# Payer Name               Erik Smith
# CC Number           213140353657882
# tip%                          18.62
# Name: Sun9679, dtype: object

# %%
df = df.append(one_row) # append not working
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12892\4030608447.py in ?()
# ----> 1 df = df.append(one_row)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6198             and name not in self._accessors
#    6199             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6200         ):
#    6201             return self[name]
# -> 6202         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
