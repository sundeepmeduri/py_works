# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/sunbi/OneDrive/Desktop/DataAnalysis/data/kc_house_data.csv')

# %% [markdown]
# # df.at is similar to df.loc & df.iat is similar to df.iloc but can access individual cell value
# # only one cell

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.at[4, 'id']
# Out:
# 1954400510

# %%
df.at[0, 'bedrooms']
# Out:
# 3

# %%
df.at[0, 'bedrooms'] = 4

# %%
df.at[0, 'bedrooms']
# Out:
# 4

# %%
df.loc[0].at['price']
# Out:
# 221900.0

# %%
df.iloc[0].at['price']
# Out:
# 221900.0

# %%
df.at[0,'price'] = 100.0

# %%
df.at[0,'price']
# Out:
# 100.0

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000     100.0         4       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.loc[0,'price']
# Out:
# 100.0

# %%
df.iloc[0,2]
# Out:
# 100.0

# %%
df.iat[0, 2]
# Out:
# 100.0

# %%
df.iat[4,3]
# Out:
# 3

# %% [markdown]
# # using loc

# %%
df = pd.read_csv('C:/Users/sunbi/OneDrive/Desktop/DataAnalysis/data/kc_house_data.csv')

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.loc[0:4,['id', 'date', 'floors'] ]
# Out:
#            id             date  floors
# 0  7129300520  20141013T000000     1.0
# 1  6414100192  20141209T000000     2.0
# 2  5631500400  20150225T000000     1.0
# 3  2487200875  20141209T000000     1.0
# 4  1954400510  20150218T000000     1.0

# %%
df['id'].count()
# Out:
# 21613

# %%
df['id'].unique().size # there are some duplicated but still using id as index
# Out:
# 21436

# %%
df = df.set_index('id')

# %%
df.index
# Out:
# Index([7129300520, 6414100192, 5631500400, 2487200875, 1954400510, 7237550310,
#        1321400060, 2008000270, 2414600126, 3793500160,
#        ...
#        7852140040, 9834201367, 3448900210, 7936000429, 2997800021,  263000018,
#        6600060120, 1523300141,  291310100, 1523300157],
#       dtype='int64', name='id', length=21613)

# %%
df
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.loc[7129300520, ['date', 'floors']]
# Out:
# date      20141013T000000
# floors                1.0
# Name: 7129300520, dtype: object

# %%
df.loc[7129300520:1954400510, ['date', 'floors']]
# Out:
#                        date  floors
# id
# 7129300520  20141013T000000     1.0
# 6414100192  20141209T000000     2.0
# 5631500400  20150225T000000     1.0
# 2487200875  20141209T000000     1.0
# 1954400510  20150218T000000     1.0

# %%
# updated value of a column
df.loc[7129300520:1954400510, ['floors']] = 10

# %%
df
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
# all the columns in selected row updates to 10
df.loc[1523300157] = 10

# %%
df
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157               10      10.0        10      10.00           10
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %% [markdown]
# # using iloc

# %%
df.iloc[0:5,[0,6]]
# Out:
#                        date  floors
# id
# 7129300520  20141013T000000     1.0
# 6414100192  20141209T000000     2.0
# 5631500400  20150225T000000     1.0
# 2487200875  20141209T000000     1.0
# 1954400510  20150218T000000     1.0
